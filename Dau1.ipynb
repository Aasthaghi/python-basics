# %%
print("hello")
# Out:
# hello

# %%
age=10
Age=20
print(Age)
# Out:
# 20

# %%
x=y=z="Hello There!"
print(z)
# Out:
# Hello There!

# %%
fruits=("apple",  "cherry", "banana")
print(fruits)
# Out:
# ('apple', 'cherry', 'banana')

# %%
fruits={"apple", "cherry", "cherry", "banana"}
print(fruits)
# Out:
# {'cherry', 'apple', 'banana'}

# %%
for i in range(0,6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x=5.3
type(x)
print(x)
# Out:
# 5.3

# %%
x=int(x)
print(x)
# Out:
# 5

# %%
a= "Nepal is a beautiful country" #[start:step:stop]
print(a[:-1])
# Out:
# Nepal is a beautiful countr
