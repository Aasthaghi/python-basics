# %%
file=open("hello.ipynb", 'x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 file=open("hello.ipynb", 'x')
#
# FileExistsError: [Errno 17] File exists: 'hello.ipynb'

# %%
print("hello")
# Out:
# hello

# %%
file=open("data.txt", 'r')
content=file.read()
print(content)
file.close()
# Out:
# hi there!

# %%
file=open("data.txt",'w')
file.write("i am Aastha Ghimire")
file.close()

# %%
file=open("data.txt",'a')
file.write("\nNew line added")
file.close()

# %%
try:

    num=int(input("enter a number:"))
    print(10/num)

except:
    print("error occured!")

finally:
    print("this block will always excuted!")
# Out:
# 5.0
# this block will always excuted!

# %%
class Student:
    name= "Ram"

s1= Student()
print(s1.name)
# Out:
# Ram

# %%
class Student:
    def __init__(self,name):
        self.name=name

s1=Student("Ram")
print(s1.name)
# Out:
# Ram

# %%
class Animal:
    def sound(self):
        print ("Animal can mske sounds")


class Dog(Animal):
    pass
    
d=Dog()
d.sound()
# Out:
# Animal can mske sounds

# %%
#postgres install garni ane pgadmin jaso kei install vaxa ke nai check garni
